# %%
import tensorflow as tf
import os

saved_speed_model = './speed_model/'
saved_angle_model = './angle_model/'

speed_model = tf.keras.models.load_model(saved_speed_model)
angle_model = tf.keras.models.load_model(saved_angle_model)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 7
#       4 saved_speed_model = './speed_model/'
#       5 saved_angle_model = './angle_model/'
# ----> 7 speed_model = tf.keras.models.load_model(saved_speed_model)
#       8 angle_model = tf.keras.models.load_model(saved_angle_model)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204       filepath = path_to_string(filepath)
#     205       if isinstance(filepath, str):
# --> 206         return saved_model_load.load(filepath, compile, options)
#     208 raise IOError(
#     209     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     210     'available) or SavedModel.')
#
# ...
